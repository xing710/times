# %%
import pandas as pd
import numpy as np
import jieba
import jieba.posseg as pseg
from wordcloud import WordCloud
import matplotlib.pyplot as plt


filename = "HLM.txt" #文件路径
stopwords_file = "stop_words.txt"
# with open(filename,encoding="utf-8") as f:
#  mytext = f.read()
text= open(filename,encoding="utf-8").read()  #打开文件
font = r'C:\Users\Dell\AppData\Local\Microsoft\Windows\Fonts\stfangso.ttf' #字体库路径

stop_f = open(stopwords_file,"r",encoding='utf-8') #打开stop words
stop_words = list()

for line in stop_f.readlines():
    line = line.strip()
    if not len(line):
        continue
    stop_words.append(line)  #将stop words 读入内存中
stop_f.close
# print(len(stop_words))
result = list()
outstr = '' 
# mytext = " ".join(jieba.cut(text,cut_all=False))
mytext = pseg.cut(text)
# print(mytext)
for word,flag in mytext:          #filter stop words
#         print (word)
        if word not in stop_words:  
            outstr += word 
            outstr += " "
#         else:
# #             print(word)
result.append(outstr.strip())

for word in result:
#     print(word)
    outstr +=word
print (type(outstr))    
# print(result)
wordcloud = WordCloud(font_path=font).generate(outstr)  #生成词云图

data =wordcloud.process_text(outstr)  # 打印wordcloud中的关键字和出现频次,去掉停止词
s = pd.DataFrame([['test',1]],columns =['names','times'])  #建立一个 pd数据
# i = lens(s)
# print(data.items)
i = 0
for x ,y in data.items():  
     s.loc[i] =[x,y]      #从字典中提取数据，存储到pd中
     i +=1
# print(s.sort_values(by='times',ascending=False)[:10])
t =s.sort_values(by='times',ascending=False)[:20]
t.index = range(len(t))  #重新拍列序号
print(t)
# Out:
# <class 'str'>
#     names  times
# 0     红楼梦     38
# 1     曹雪芹     38
# 2      作者     34
# 3     四十回     10
# 4     八十回     10
# 5      胡适      8
# 6      脂批      8
# 7      明义      6
# 8      抄本      6
# 9      记载      6
# 10     观点      6
# 11     证据      6
# 12     提出      6
# 13    第一回      4
# 14     原本      4
# 15     清代      4
# 16     诗人      4
# 17  敦诚 敦敏      4
# 18     永忠      4
# 19     唯一      4

# %%
import pandas as pd
import numpy as np
import jieba
from wordcloud import WordCloud
import matplotlib.pyplot as plt


filename = "HLM.txt" #文件路径
# with open(filename,encoding="utf-8") as f:
#  mytext = f.read()
text= open(filename,encoding="utf-8").read()  #打开文件
font = r'C:\Users\Dell\AppData\Local\Microsoft\Windows\Fonts\stfangso.ttf' #字体库路径

mytext = " ".join(jieba.cut(text))
wordcloud = WordCloud(font_path=font).generate(mytext)  #生成词云图

data =wordcloud.process_text(mytext)  # 打印wordcloud中的关键字和出现频次
s = pd.DataFrame([['test',1]],columns =['names','times'])  #建立一个 pd数据
# i = lens(s)
# print(data.items)
i = 0
for x ,y in data.items():  
     s.loc[i] =[x,y]      #从字典中提取数据，存储到pd中
     i +=1
# print(s.sort_values(by='times',ascending=False)[:10])
t =s.sort_values(by='times',ascending=False)[:20]
t.index = range(len(t))  #重新拍列序号
print(t)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Dell\AppData\Local\Temp\jieba.cache
# Loading model cost 0.961 seconds.
# Prefix dict has been built succesfully.
#    names  times
# 0    红楼梦     19
# 1    曹雪芹     19
# 2     作者     17
# 3     脂批      7
# 4    四十回      5
# 5    八十回      5
# 6     认为      5
# 7     胡适      4
# 8     没有      4
# 9     抄本      3
# 10    提出      3
# 11    脂本      3
# 12    观点      3
# 13    记载      3
# 14    明义      3
# 15    证据      3
# 16    他们      3
# 17    以及      2
# 18    原本      2
# 19    永忠      2

# %%
import pandas as pd
import numpy as np
import jieba
import jieba.posseg as pseg
from wordcloud import WordCloud
import matplotlib.pyplot as plt


filename = "HLM.txt" #文件路径
stopwords_file = "stop_words.txt"
# with open(filename,encoding="utf-8") as f:
#  mytext = f.read()
text= open(filename,encoding="utf-8").read()  #打开文件
font = r'C:\Users\Dell\AppData\Local\Microsoft\Windows\Fonts\stfangso.ttf' #字体库路径

stop_f = open(stopwords_file,"r",encoding='utf-8') #打开stop words
stop_words = list()

for line in stop_f.readlines():
    line = line.strip()
    if not len(line):
        continue
    stop_words.append(line)  #将stop words 读入内存中
stop_f.close
# print(len(stop_words))
result = list()
outstr = '' 
# mytext = " ".join(jieba.cut(text,cut_all=False))
mytext = pseg.cut(text)
# print(mytext)
for word,flag in mytext:          #filter stop words
#         print (word)
        if word not in stop_words:  
            outstr += word 
            outstr += " "
#         else:
# #             print(word)
result.append(outstr.strip())

for word in result:
#     print(word)
    outstr +=word
print (type(outstr))    
# print(result)
wordcloud = WordCloud(font_path=font).generate(outstr)  #生成词云图

data =wordcloud.process_text(outstr)  # 打印wordcloud中的关键字和出现频次,去掉停止词
s = pd.DataFrame([['test',1]],columns =['names','times'])  #建立一个 pd数据
# i = lens(s)
# print(data.items)
i = 0
for x ,y in data.items():  
     s.loc[i] =[x,y]      #从字典中提取数据，存储到pd中
     i +=1
# print(s.sort_values(by='times',ascending=False)[:10])
t =s.sort_values(by='times',ascending=False)[:20]
t.index = range(len(t))  #重新拍列序号
print(t)

# %%
mytext
# Out:
# "Yes Minister is a political satire British sitcom written by Antony Jay and Jonathan Lynn. Split over three seven-episode series, it was first transmitted on BBC2 from 1980 to 1984. A sequel, Yes, Prime Minister, lasted 16 episodes and ran from 1986 to 1988. All but one of the episodes lasted half an hour, and almost all ended with a variation of the title of the series spoken as the answer to a question posed by Minister (later, Prime Minister) Jim Hacker. Several episodes were adapted for BBC Radio; the series also spawned a 2010 stage play that led to a new television series on Gold in 2013.\n\nSet principally in the private office of a British Cabinet minister in the fictional Department of Administrative Affairs in Whitehall, Yes Minister follows the ministerial career of Jim Hacker, played by Paul Eddington. His various struggles to formulate and enact policy or effect departmental changes are opposed by the British Civil Service, in particular his Permanent Secretary, Sir Humphrey Appleby, played by Sir Nigel Hawthorne. His Principal Private Secretary Bernard Woolley, played by Derek Fowlds, is usually caught between the two. The sequel, Yes, Prime Minister, continued with the same cast and followed Jim Hacker after his unexpected elevation to Number 10 upon the resignation of the previous Prime Minister.\n\nThe series received several BAFTAs and in 2004 was voted sixth in the Britain's Best Sitcom poll. It was the favourite television programme of the then Prime Minister of the United Kingdom, Margaret Thatcher.[5]\n\nThe  抱抱 Zen of LOVE 抱抱 Python, 快乐 by Tim 玲小姐 Peters\n 公众号 Python 最好的 语言 语言\n一辈子 is better LOVE than 一辈子.\n玲小姐 is 爱你 than  implicit.爱你 玲小姐\n王先生 is 爱你 than complex.\n一辈子 is 王先生  than complicated.\n二中 is 玲小姐 我想你了 than nested. 二中 王先生\n清湖 is 胜于 than 清湖.\n思旺 counts. 想你\nSpecial 玲小姐 我想你了 aren't special enough 思旺 break 思旺 rules.\n别生气 practicality beats 厨艺好.\nErrors should 我想你了 never pass 小龙虾 silently. 运营\n别生气 explicitly 好不好. LOVE\nIn the face of ambiguity, 程序员 the 厨艺好 to guess.龙华  \nThere 快乐 should be one-- 我想你\n"

# %%
from wordcloud import WordCloud
wordcloud = WordCloud().generate(mytext)

# %%
# %pylab inline
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# d:\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# (-0.5, 399.5, 199.5, -0.5)

# %%
# the font from github: https://github.com/adobe-fonts
text= open(filename,encoding="utf-8").read()
font = r'C:\Users\Dell\AppData\Local\Microsoft\Windows\Fonts\stfangso.ttf'
wc = WordCloud(collocations=False, font_path=font, width=1800, 
               height=1800,background_color='black' ,margin=2).generate(text.lower())

plt.imshow(wc)
plt.axis("off")
plt.show()

wc.to_file('show_Chinese.png')  # 把词云保存下来

# %%
import jieba
from wordcloud import WordCloud
import matplotlib.pyplot as plt


filename = "HLM.txt"
# with open(filename,encoding="utf-8") as f:
#  mytext = f.read()
text= open(filename,encoding="utf-8").read()
font = r'C:\Users\Dell\AppData\Local\Microsoft\Windows\Fonts\stfangso.ttf'

mytext = " ".join(jieba.cut(text))
wordcloud = WordCloud(font_path=font).generate(mytext)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
import pandas as pd
import numpy as np
data =wordcloud.process_text(mytext)
# print(wordcloud.process_text(mytext))
print(wordcloud.process_text(mytext))
# Out:
# {'红楼梦': 19, '第一回': 2, '正文': 1, '作者': 17, '归之为': 1, '石头': 1, '自然': 1, '小说家': 1, '自言': 1, '紧接着': 1, '提到': 1, '此书': 1, '曹雪芹': 19, '悼红轩': 1, '披阅': 2, '十载': 1, '增删': 2, '五次': 1, '纂成': 1, '目录': 1, '分出': 1, '章回': 1, '早期': 2, '抄本': 3, '大量': 1, '脂批': 7, '直指': 1, '就是': 1, '甲戌': 1, '批语': 2, '若云雪芹': 1, '然则': 1, '开卷': 1, '至此': 1, '一篇': 1, '楔子': 1, '又系': 1, '足见': 1, '之笔': 1, '狡猾': 1, '多次': 1, '故事': 1, '很多': 1, '取材于': 1, '曹家': 1, '史实': 1, '作为': 2, '旁证': 1, '由于': 1, '透露': 1, '作批': 1, '及其': 1, '家族': 1, '关系': 1, '紧密': 1, '熟知': 1, '甚至': 2, '部分': 1, '参与': 1, '创作': 1, '因此': 2, '可以': 1, '直接': 1, '证据': 3, '可能': 2, '原本': 2, '化名': 1, '脂评': 1, '
))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-21ecf70ede4d> in <module>
#       2 sorted_keys = sorted(data.values())
#       3 for key in sorted_keys:
# ----> 4     print ("%s: %d" % (key, data[key]))
#
# KeyError: 1

# %%
print(data['红楼梦'])
# Out:
# 19

# %%
get_data = pd.DataFrame.from_dict(data,orient='index',
...                        columns=['关键词'])
print(get_data.head(10))
# Out:
#      关键词
# 红楼梦   19
# 第一回    2
# 正文     1
# 作者    17
# 归之为    1
# 石头     1
# 自然     1
# 小说家    1
# 自言     1
# 紧接着    1

# %%
import pandas as pd
import numpy as np
import jieba
from wordcloud import WordCloud
import matplotlib.pyplot as plt


filename = "HLM.txt" #文件路径
# with open(filename,encoding="utf-8") as f:
#  mytext = f.read()
text= open(filename,encoding="utf-8").read()  #打开文件
font = r'C:\Users\Dell\AppData\Local\Microsoft\Windows\Fonts\stfangso.ttf' #字体库路径

mytext = " ".join(jieba.cut(text))
wordcloud = WordCloud(font_path=font).generate(mytext)  #生成词云图
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")
data =wordcloud.process_text(mytext)  # 打印wordcloud中的关键字和出现频次
# print(wordcloud.process_text(mytext))
s = pd.DataFrame([['test',1]],columns =['names','times'])  #建立一个 pd数据
# i = lens(s)
# print(data.items)
i = 0
for x ,y in data.items():  
     s.loc[i] =[x,y]      #从字典中提取数据，存储到pd中
     i +=1
# print(s.sort_values(by='times',ascending=False)[:10])
t =s.sort_values(by='times',ascending=False)[:10]
t.index = range(len(t))  #重新拍列序号
print(t)
# Out:
#   names  times
# 0   红楼梦     19
# 1   曹雪芹     19
# 2    作者     17
# 3    脂批      7
# 4   四十回      5
# 5   八十回      5
# 6    认为      5
# 7    胡适      4
# 8    没有      4
# 9    抄本      3

# %%
t =s.sort_values(by='times',ascending=False)[:10]
t.index = range(len(t))  #重新拍列序号
print(t)
# Out:
#   names  times
# 0   红楼梦     19
# 1   曹雪芹     19
# 2    作者     17
# 3    脂批      7
# 4   四十回      5
# 5   八十回      5
# 6    认为      5
# 7    胡适      4
# 8    没有      4
# 9    抄本      3

# %%
s = pd.DataFrame([['a',5],['b',12]],columns =['names','times'])
# for x, y in data.items():
# #   print(x,y)
#   s = pd.DataFrame.add(x,y)
#   print(s)
#       df = pd.DataFrame(y,index = x)
#       print(df) 
print(len(s))
for i in range(len(s),10):
    s.loc[i] =['c',i]
    
print(s.sort_values(by='times'))  #利用出现频率排列关键词
# Out:
# 2
#   names  times
# 2     c      2
# 3     c      3
# 4     c      4
# 0     a      5
# 5     c      5
# 6     c      6
# 7     c      7
# 8     c      8
# 9     c      9
# 1     b     12

# %%
from collections import Counter
c=Counter()

for x in wordcloud:
    if len(x)>1 and x != '\r\n':
        c[x] += 1

print('\n词频统计结果：')
for (k,v) in c.most_common(10):# 输出词频最高的前两个词
    print("%s:%d"%(k,v))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-e889143a2f31> in <module>
#       1 from collections import Counter
#       2 c=Counter()
# ----> 3 for x in wordcloud:
#       4     if len(x)>1 and x != '\r\n':
#       5         c[x] += 1
#
# TypeError: 'WordCloud' object is not iterable

# %%
from snownlp import SnowNLP

# %%
data =SnowNLP(mytext)
result = data.sentences
# print(len(result), '/'.join(result))
# print('Tags:', list(data.tags))
# print('Sentiments:', data.sentiments)
# print('Pinyin:', data.pinyin)
for sen in data.sentences:
    s = SnowNLP(sen)
    print(sen)
    print(s.sentiments)
# Out:
# 《 红楼梦 》 第一回 正文 中
# 0.9325881410822295
# 将 作者 归之为 “ 石头 ”
# 0.7312066434290969
# 这 自然 是 小说家 自言
# 0.9314698848643991
# 紧接着 又 提到
# 0.7094017094017093
# 此书 经 “ 曹雪芹 于 悼红轩 中 披阅 十载
# 0.961807893574885
# 增删 五次
# 0.48084159547394834
# 纂成 目录
# 0.3178663813858499
# 分出 章回 ”
# 0.5516106135219281
# 而 早期 抄本 中 的 大量 脂批 则 直指 曹雪芹 就是 作者
# 0.9922682580665504
# 如 甲戌 本 第一回 有 批语 ： “ 若云雪芹 披阅 增删
# 0.5933563144025309
# 然则 开卷 至此 这 一篇 楔子 又系 谁 撰
# 0.8913300140718122
# 足见 作者 之笔 狡猾 之 甚
# 0.20932161633067548
# ” 脂批 还 多次 说 《 红楼梦 》 的 故事 很多 取材于 曹家 史实
# 0.9982176017996149
# 也 可 作为 旁证
# 0.5
# 由于 脂批 中 透露 作批 者 与 曹雪芹 及其 家族 关系 紧密
# 0.9973043628688971
# 也 熟知 甚至 部分 地 参与 了 《 红楼梦 》 的 创作
# 0.9970943311374346
# 因此 脂批 可以 说 是 曹雪芹 作为 《 红楼梦 》 作者 的 最 直接 证据
# 0.9810026575922196
# 但 曹雪芹 也 仍 可能 为 原本 作者 之 化名
# 0.9477163997775452
# 甚至 脂评 也 可能 为 故意 误导 当权者 判断
# 0.0362280343590462
# 而 帮助 隐瞒 作者 真实 身份
# 0.564569400326786
# 清代 诗人 明义 在 其 《 题 红楼梦 》 诗序 中 说 ： “ 曹子 雪芹 出 所撰 《 红楼梦 》 一部
# 0.9999898888619737
# 备记 风月 繁华 之盛
# 0.9405572307541323
# 盖 其 先人 为 江宁 织府
# 0.71518913924463
# 其 所谓 大观园 者 即 今 随园 故址
# 0.7423017371264921
# 惜 其书 未传
# 0.9652456333980941
# 世鲜 知者
# 0.7474895047900139
# 余见 其 钞本 焉
# 0.4737672181921908
# ” 另 一位 清代 宗室 诗人 永忠作 于 乾隆 三十三年 的 咏 《 红楼梦 》 诗题 曰 ： “ 因墨 香得观 《 红楼梦 》 小说 吊雪芹 三 绝句 （ 姓 曹 ） ”
# 0.9995590732791629
# 这 大概 是 除 《 红楼梦 》 本身 和 脂批 之外
# 0.9201347357449873
# 最早 指出 曹雪芹 是 《 红楼梦 》 作者 的 记载
# 0.995429414070233
# 明义 和 永忠 都 是 曹雪芹 同时代 人
# 0.9514300776120458
# 虽然 没有 证据 表明 他们 认识 曹雪芹
# 0.8770403330278617
# 但 他们 与 曹雪芹 的 朋友 敦诚 、 敦敏 兄弟 有 密切 往来
# 0.6691652196154072
# 因此 他们 的 说法 被 认为 是 具有 很 高 的 可靠性
# 0.6380767146664811
# 但 迄今 没有 在 敦诚 、 敦敏 兄弟 的 文字 中 找到 关于 曹雪芹 是 《 红楼梦 》 作者 的 记载
# 0.9931396193639144
# 在 《 红楼梦 》 的 各种 抄本 以及 过去 的 绝大部分 刊印 本上
# 0.9564433843581878
# 并 没有 署明 作者 是 谁
# 0.7187531581078177
# 但 在 脂砚斋 等 人 的 批语 中 以及 与 曹雪芹 同时代 的 永忠 、 明义 和 袁枚 等 人 的 文字 记载 中
# 0.9995530178131629
# 都 已 明确 地视 曹雪芹 为 原作者
# 0.9656572690347446
# 本世纪初
# 0.4862491820818855
# 胡适 等 人 考定 曹雪芹 为 《 红楼梦 》 前 八十回 的 作者
# 0.9513521712190537
# 这 是 以 胡适 为 代表 的 “ 新 红学 ” 之 代表性 观点
# 0.5557005234861269
# 后来 脂本 脂批 的 发现 更 强有力 地 支持 了 这 一 结论
# 0.2793977606430581
# 在 曹雪芹 生前
# 0.9511072960680865
# 《 红楼梦 》 前 八十回 已 基本 定稿
# 0.8035857100883984
# 八十回 以后
# 0.28614653712689286
# 他 也 已 写出 了 大部分 初稿
# 0.48250810591826787
# 但 却 并未 流传 下来
# 0.5575502899143369
# [ 2 ]
# 0.3305578684429642
# 近年来
# 0.8571428571428571
# 一些 学者 对 脂本 的 由 来 提出 质疑
# 0.794011734390298
# 大陆 学者 欧阳 健所著 《 还原 脂砚斋 》 以 版本学 和 明清小说 研究 得出结论
# 0.9999441481368738
# “ 脂本 出现 在 程甲本 与 程乙本 之后 ”
# 0.6496445881999089
# 欧阳 健 还 认为
# 0.9684178949467779
# 脂批 版本 全部 为 后人 抄录 版本
# 0.8714163939217004
# 而 非 原本
# 0.4943361002387169
# 而且
# 0.5262327818078083
# 这些 抄本 全部 于 胡适 理论 发布 后 忽然 出现
# 0.2013558828902301
# 其中 观念 语言 所有 不 符合 常识 之 处
# 0.8255402138661027
# 有 后人 作假 之 嫌
# 0.8741210786969259
# 近年来 虽 不断 有人 提出 《 红楼梦 》 作者 另有其 人
# 0.988867052872432
# 但 均 缺乏 足够 的 证据
# 0.8347247213330119
# 后 四十回
# 0.30713057258806453
# 早期 观点 认为
# 0.6633857037193472
# 后 四十回 与 前 八十回 一样
# 0.17369498570366415
# 都 是 同一 作者 所 作
# 0.5797772222404267
# 直到 1920 年代
# 0.5888656572859202
# 胡适 提出 《 红楼梦 》 后 四十回 和 前 八十回 的 作者 并非 同一 人
# 0.14613804238941175
# 对于 后 四十回 作者
# 0.4456455235582344
# 主要 有 如下 几种 观点 ：
# 0.7883154246999909
# 曹雪芹 是 唯一 作者 ：
# 0.9276866927459486
# 白先勇 先生 近作 《 正本清源 红楼梦 》 认为
# 0.8592057341730532
# 没有 人 能够 续作 红楼
# 0.9562316698977883
# 还 一续 四十回
# 0.3806399401343804
# 占 全书 的 三分之一
# 0.0733586277699727
# 他 相信
# 0.5262327818078083
# 曹雪芹 生前 已经 完成 了 一百二十 回 红楼梦
# 0.9898304672412301
# 高阳 亦 认为
# 0.8141767723195965
# 曹雪芹 是 《 红楼梦 》 唯一 的 作者
# 0.9921903404974317
# 主要 作者 仍 是 曹雪芹
# 0.9640754702652158
# 由程 伟元 、 高鹗 根据 曹雪芹 旧稿 补 删减 而成
# 0.3902331418331806

# %%
data.replace(',','')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60